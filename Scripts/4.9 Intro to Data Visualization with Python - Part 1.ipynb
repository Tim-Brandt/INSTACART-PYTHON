# %% [markdown]
# # Step 1 - Download customer data set &  add it to “Original Data” folder

# %% [markdown]
# Done

# %% [markdown]
# # Step 2 - Create a new notebook in your “Scripts” folder for part 1 of this task

# %% [markdown]
# Done

# %% [markdown]
# # Step 3 - Import analysis libraries & new customer data set as a dataframe

# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Import Data

# %%
path = r'C:\Users\Timbr\OneDrive\Desktop\Career Foundry\Data Immersion\Achievement 4\Instacart Basket Analysis - Achievement 4 -  Tim Brandt'

# %%
df_customers = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'customers.csv'))

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged_V3.pkl'))

# %% [markdown]
# # Step 4 - Wrangle the data so it follows consistent logic

# %%
df_customers.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_customers.shape
# Out:
# (206209, 10)

# %%
df_customers.describe()
# Out:
#              user_id            Age   n_dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %%
#checking for blanks or nan values
df_customers['Gender'].value_counts(dropna = False)
# Out:
# Gender
# Male      104067
# Female    102142
# Name: count, dtype: int64

# %%
df_customers['STATE'].value_counts(dropna = False)
# Out:
# STATE
# Florida                 4044
# Colorado                4044
# Illinois                4044
# Alabama                 4044
# District of Columbia    4044
# Hawaii                  4044
# Arizona                 4044
# Connecticut             4044
# California              4044
# Indiana                 4044
# Arkansas                4044
# Alaska                  4044
# Delaware                4044
# Iowa                    4044
# Idaho                   4044
# Georgia                 4044
# Wyoming                 4043
# Mississippi             4043
# Oklahoma                4043
# Utah                    4043
# New Hampshire           4043
# Kentucky                4043
# Maryland                4043
# Rhode Island            4043
# Massachusetts           4043
# Michigan                4043
# New Jersey              4043
# Kansas                  4043
# South Dakota            4043
# Minnesota               4043
# Tennessee               4043
# New York                4043
# ...

# %%
df_customers['Age'].value_counts(dropna = False)
# Out:
# Age
# 19    3329
# 55    3317
# 51    3317
# 56    3306
# 32    3305
#       ...
# 65    3145
# 25    3127
# 66    3114
# 50    3102
# 36    3101
# Name: count, Length: 64, dtype: int64

# %%
df_customers['fam_status'].value_counts(dropna = False)
# Out:
# fam_status
# married                             144906
# single                               33962
# divorced/widowed                     17640
# living with parents and siblings      9701
# Name: count, dtype: int64

# %%
df_customers['income'].value_counts(dropna = False)
# Out:
# income
# 57192     10
# 95891     10
# 95710     10
# 97532      9
# 98675      9
#           ..
# 73141      1
# 71524      1
# 74408      1
# 44780      1
# 148828     1
# Name: count, Length: 108012, dtype: int64

# %%
df_customers['n_dependants'].value_counts(dropna = False)
# Out:
# n_dependants
# 0    51602
# 3    51594
# 1    51531
# 2    51482
# Name: count, dtype: int64

# %%
#changing a column names in customer
df_customers.rename(columns = {'Surnam' : 'Last Name'}, inplace = True)

# %%
df_customers.head()
# Out:
#    user_id First Name Last Name  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_customers.rename(columns = {'STATE' : 'State'}, inplace = True)

# %%
df_customers.rename(columns = {'n_dependants' : 'dependants'}, inplace = True)

# %%
df_customers.rename(columns = {'fam_status' : 'Marital Status'}, inplace = True)

# %%
df_customers.head()
# Out:
#    user_id First Name Last Name  Gender       State  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    dependants Marital Status  income
# 0           3        married  165665
# 1           0         single   59285
# 2           2        married   99568
# 3           0         single   42049
# 4           1        married   40374

# %%
#changing the data type to string for user id in customers df
df_customers['user_id'] = df_customers['user_id'].astype('str')

# %%
#changing the data type to string for user id in ords_prods_merge df
df_ords_prods_merge['user_id'] = df_ords_prods_merge['user_id'].astype('str')

# %%
df_customers['user_id'].dtype
# Out:
# dtype('O')

# %%
df_ords_prods_merge['user_id'].dtype
# Out:
# dtype('O')

# %%
df_ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434212 entries, 0 to 32434211
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 object
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  _merge                  category
#  15  busiest_day             object
#  16  busiest_days            object
#  17  busiest_period_of_day   object
#  18  max_order               int64
#  19  loyalty_flag            object
#  20  average_price           float64
# ...

# %% [markdown]
# # Step 5 - Complete the fundamental data quality & consistency checks

# %%
#checking for missing values again
df_customers.isnull().sum()
# Out:
# user_id               0
# First Name        11259
# Last Name             0
# Gender                0
# State                 0
# Age                   0
# date_joined           0
# dependants            0
# Marital Status        0
# income                0
# dtype: int64

# %%
df_customers['First Name'].value_counts(dropna = False)
# Out:
# First Name
# NaN        11259
# Marilyn     2213
# Barbara     2154
# Todd        2113
# Jeremy      2104
#            ...
# Merry        197
# Eugene       197
# Garry        191
# Ned          186
# David        186
# Name: count, Length: 208, dtype: int64

# %%
#looking for duplicates
df_dups = df_customers[df_customers.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Last Name, Gender, State, Age, date_joined, dependants, Marital Status, income]
# Index: []

# %% [markdown]
# # Step 6 - Combine customer data with prepared Instacart data

# %%
df_customers.head()
# Out:
#   user_id First Name Last Name  Gender       State  Age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    dependants Marital Status  income
# 0           3        married  165665
# 1           0         single   59285
# 2           2        married   99568
# 3           0         single   42049
# 4           1        married   40374

# %%
df_ords_prods_merge.head()
# Out:
#    order_id user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329       1    prior             1          2                  8
# 1   2398795       1    prior             2          3                  7
# 2    473747       1    prior             3          3                 12
# 3   2254736       1    prior             4          4                  7
# 4    431534       1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     NaN         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   prices     busiest_day    busiest_days  busiest_period_of_day max_order  \
# ...

# %%
df_merged_clean = df_customers.merge(df_ords_prods_merge, on = 'user_id', indicator = True)

# %%
df_merged_clean.head()
# Out:
#   user_id First Name Last Name  Gender     State  Age date_joined  dependants  \
# 0   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017           3
# 1   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017           3
# 2   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017           3
# 3   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017           3
# 4   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017           3
#
#   Marital Status  income  ...     busiest_day    busiest_days  \
# 0        married  165665  ...  Regularly busy    Busiest days
# 1        married  165665  ...  Regularly busy  Regularly days
# 2        married  165665  ...  Regularly busy    Busiest days
# 3        married  165665  ...  Regularly busy  Regularly days
# 4        married  165665  ...  Regularly busy    Slowest days
#
#    busiest_period_of_day  max_order  loyalty_flag  average_price  \
# ...

# %%
#dropping the merge column
df_merged_clean = df_merged_clean.drop(columns = ['_merge'])

# %%
#checking its dropped
df_merged_clean.head()
# Out:
#   user_id First Name Last Name  Gender     State  Age date_joined  dependants  \
# 0   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017           3
# 1   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017           3
# 2   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017           3
# 3   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017           3
# 4   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017           3
#
#   Marital Status  income  ...  prices     busiest_day    busiest_days  \
# 0        married  165665  ...     9.0  Regularly busy    Busiest days
# 1        married  165665  ...     9.0  Regularly busy  Regularly days
# 2        married  165665  ...     9.0  Regularly busy    Busiest days
# 3        married  165665  ...    12.6  Regularly busy  Regularly days
# 4        married  165665  ...    12.6  Regularly busy    Slowest days
#
#    busiest_period_of_day  max_order  loyalty_flag  average_price  \
# ...

# %% [markdown]
# # Step 7 - Ensure notebook has logical titles, section headings, etc,

# %% [markdown]
# Done

# %% [markdown]
# # Step 8 - Export new dataframe as a pickle file

# %%
# Export data to pkl
df_merged_clean.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged_V4.pkl'))
