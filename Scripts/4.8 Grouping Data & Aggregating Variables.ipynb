# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Importing Dataframes

# %%
path = r'C:\Users\Timbr\OneDrive\Desktop\Career Foundry\Data Immersion\Achievement 4\Instacart Basket Analysis - Achievement 4 -  Tim Brandt'

# %%
df_orders_products_merged = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged_V2.pkl'))

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0         Soda        77              7     9.0   both  Regularly busy
# 1         Soda        77              7     9.0   both  Regularly busy
# 2         Soda        77              7     9.0   both  Regularly busy
# 3         Soda        77              7     9.0   both      Least busy
# 4         Soda        77              7     9.0   both      Least busy
#
#      busiest_days busiest_period_of_day
# 0  Regularly days        Average Orders
# 1    Slowest days        Average Orders
# 2    Slowest days           Most Orders
# 3    Slowest days        Average Orders
# 4    Slowest days           Most Orders

# %%
df_orders_products_merged.shape
# Out:
# (32434212, 18)

# %%
# Creating subset
df = df_orders_products_merged[:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head(10)
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
# 5   3367565        1    prior             6          2                  7
# 6    550135        1    prior             7          1                  9
# 7   3108588        1    prior             8          1                 14
# 8   2295261        1    prior             9          1                 16
# 9   2550362        1    prior            10          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
# 5                    19.0         196                  1          1
# 6                    20.0         196                  1          1
# 7                    14.0         196                  2          1
# 8                     0.0         196                  4          1
# 9                    30.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0         Soda        77              7     9.0   both  Regularly busy
# 1         Soda        77              7     9.0   both  Regularly busy
# 2         Soda        77              7     9.0   both  Regularly busy
# 3         Soda        77              7     9.0   both      Least busy
# 4         Soda        77              7     9.0   both      Least busy
# 5         Soda        77              7     9.0   both  Regularly busy
# 6         Soda        77              7     9.0   both  Regularly busy
# 7         Soda        77              7     9.0   both  Regularly busy
# 8         Soda        77              7     9.0   both  Regularly busy
# 9         Soda        77              7     9.0   both      Least busy
#
#      busiest_days busiest_period_of_day
# 0  Regularly days        Average Orders
# 1    Slowest days        Average Orders
# 2    Slowest days           Most Orders
# 3    Slowest days        Average Orders
# 4    Slowest days           Most Orders
# 5  Regularly days        Average Orders
# 6    Busiest days           Most Orders
# 7    Busiest days           Most Orders
# 8    Busiest days           Most Orders
# 9    Slowest days        Average Orders

# %% [markdown]
# Grouping Data

# %%
df.groupby('product_name')

# %% [markdown]
# Single Aggregation

# %%
#Single Aggregation
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Different way of finding mean of 'order_number'
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %% [markdown]
# Multiple Aggregations

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# Aggregating Data with transform

# %%
df_orders_products_merged['max_order'] = df_orders_products_merged.groupby('user_id')['order_number'].transform(np.max)

# %%
df_orders_products_merged.head(25)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   2968173       15    prior            15          1                  9
# 11   1870022       15    prior            17          2                 16
# 12   1911383       15    prior            18          2                 11
# 13   2715276       15    prior            21          1                  9
# 14    487368       15    prior            22          1                 10
# 15   2293453       19    prior             2          5                 14
# 16   1973799       19    prior             5          6                 12
# 17    532817       19    prior             7          4                 17
# 18   1573906       21    prior            10          3                 10
# 19   1593000       31    prior            10          3                  8
# 20   2231262       31    prior            17          3                 11
# 21   2580647       43    prior             6          4                 16
# 22   2187180       43    prior             9          4                 12
# 23   2497897       52    prior             1          1                  9
# 24   1318871       52    prior             2          1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
# 15                     6.0         196                  3          0
# 16                     8.0         196                 15          1
# 17                     6.0         196                  1          1
# 18                     6.0         196                  2          0
# 19                     7.0         196                 17          0
# 20                     8.0         196                 14          1
# 21                     4.0         196                  9          0
# 22                     3.0         196                  1          1
# 23                     NaN         196                  4          0
# 24                     7.0         196                  5          1
#
#    product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0          Soda        77              7     9.0   both  Regularly busy
# 1          Soda        77              7     9.0   both  Regularly busy
# 2          Soda        77              7     9.0   both  Regularly busy
# 3          Soda        77              7     9.0   both      Least busy
# 4          Soda        77              7     9.0   both      Least busy
# 5          Soda        77              7     9.0   both  Regularly busy
# 6          Soda        77              7     9.0   both  Regularly busy
# 7          Soda        77              7     9.0   both  Regularly busy
# 8          Soda        77              7     9.0   both  Regularly busy
# 9          Soda        77              7     9.0   both      Least busy
# 10         Soda        77              7     9.0   both  Regularly busy
# 11         Soda        77              7     9.0   both  Regularly busy
# 12         Soda        77              7     9.0   both  Regularly busy
# 13         Soda        77              7     9.0   both  Regularly busy
# 14         Soda        77              7     9.0   both  Regularly busy
# 15         Soda        77              7     9.0   both  Regularly busy
# 16         Soda        77              7     9.0   both  Regularly busy
# 17         Soda        77              7     9.0   both      Least busy
# 18         Soda        77              7     9.0   both  Regularly busy
# 19         Soda        77              7     9.0   both  Regularly busy
# 20         Soda        77              7     9.0   both  Regularly busy
# 21         Soda        77              7     9.0   both      Least busy
# 22         Soda        77              7     9.0   both      Least busy
# 23         Soda        77              7     9.0   both  Regularly busy
# 24         Soda        77              7     9.0   both  Regularly busy
#
#       busiest_days busiest_period_of_day  max_order
# 0   Regularly days        Average Orders         10
# 1     Slowest days        Average Orders         10
# 2     Slowest days           Most Orders         10
# 3     Slowest days        Average Orders         10
# 4     Slowest days           Most Orders         10
# 5   Regularly days        Average Orders         10
# 6     Busiest days           Most Orders         10
# 7     Busiest days           Most Orders         10
# 8     Busiest days           Most Orders         10
# 9     Slowest days        Average Orders         10
# 10    Busiest days           Most Orders         22
# 11  Regularly days           Most Orders         22
# 12  Regularly days           Most Orders         22
# 13    Busiest days           Most Orders         22
# 14    Busiest days           Most Orders         22
# 15  Regularly days           Most Orders          9
# 16  Regularly days           Most Orders          9
# 17    Slowest days        Average Orders          9
# 18    Slowest days           Most Orders         33
# 19    Slowest days        Average Orders         20
# 20    Slowest days           Most Orders         20
# 21    Slowest days           Most Orders         11
# 22    Slowest days           Most Orders         11
# 23    Busiest days           Most Orders         27
# 24    Busiest days           Most Orders         27

# %% [markdown]
# # Step 1 - Create a new notebook

# %% [markdown]
# Done

# %% [markdown]
# # Step 2 - Repeat process for entire dataframe

# %%
df_orders_products_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457687
# 2                17.277920
# 3                17.179756
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225773
# 8                15.340520
# 9                15.895474
# 10               20.197148
# 11               16.170828
# 12               15.887622
# 13               16.583304
# 14               16.757377
# 15               16.165037
# 16               17.663250
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# # Step 3 - Analyze the result

# %% [markdown]
# In every instance the average from the subset is greater then the entire data frame except for department_id 17

# %% [markdown]
# # Step 4 - Create an existing customers loyalty flag using transform() and loc()

# %% [markdown]
# Creating Flags

# %%
df_orders_products_merged.loc[df_orders_products_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['max_order'] <= 40) & (df_orders_products_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_orders_products_merged.loc[df_orders_products_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#checking totals
df_orders_products_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15891077
# Loyal customer      10293737
# New customer         6249398
# Name: count, dtype: int64

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0         Soda        77              7     9.0   both  Regularly busy
# 1         Soda        77              7     9.0   both  Regularly busy
# 2         Soda        77              7     9.0   both  Regularly busy
# 3         Soda        77              7     9.0   both      Least busy
# 4         Soda        77              7     9.0   both      Least busy
#
#      busiest_days busiest_period_of_day  max_order  loyalty_flag
# 0  Regularly days        Average Orders         10  New customer
# 1    Slowest days        Average Orders         10  New customer
# 2    Slowest days           Most Orders         10  New customer
# 3    Slowest days        Average Orders         10  New customer
# 4    Slowest days           Most Orders         10  New customer

# %%
# check accuracy
df_orders_products_merged[['user_id', 'max_order', 'loyalty_flag']].sample(30)
# Out:
#           user_id  max_order      loyalty_flag
# 13375617    23908         26  Regular customer
# 20424307    25318         67    Loyal customer
# 7386051    158727         43    Loyal customer
# 26619269   168940         77    Loyal customer
# 18750346    33195         68    Loyal customer
# 27278014   192610         25  Regular customer
# 7383548    148661         14  Regular customer
# 15007525   200112         94    Loyal customer
# 30581212     5688         16  Regular customer
# 17503006    51551         24  Regular customer
# 3386517     19289          8      New customer
# 19991085    21456         27  Regular customer
# 3510438     77161         58    Loyal customer
# 17497149   136896         66    Loyal customer
# 31343525   193561         13  Regular customer
# 4262678    159870         10      New customer
# 24497805   134771          4      New customer
# 15998020    51952         52    Loyal customer
# 29734421    88891          7      New customer
# 15199668   107186          6      New customer
# 4819918     43034         33  Regular customer
# 23061151    34565         72    Loyal customer
# 26815508    31165         24  Regular customer
# 9763887     68379         23  Regular customer
# 21175834   126308         15  Regular customer
# 8910690    105111          4      New customer
# 24778604   173369          6      New customer
# 8547793    126931         62    Loyal customer
# 4484975     97080         42    Loyal customer
# 13188423   133586         19  Regular customer

# %% [markdown]
# # Step 5 - Spending habits of customers in the 3 loyalty flag buckets

# %%
# Mean, min & max grouped by loyalty_flag
df_orders_products_merged.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.388747  1.0  99999.0
# New customer      13.294370  1.0  99999.0
# Regular customer  12.496203  1.0  99999.0

# %% [markdown]
# Observation:
#
# 1) It’s interesting that loyal customers spent less then both the new customers & regular customers
# 2) The max price seems off (1) it’s the same for all 3 buckets (Layal, New & Regular) (2) they seem way too high compared to the mean.  It suggests that the data is skewed.

# %% [markdown]
# # Step 6 - Spending flag

# %%
# Create “average_price” column using transform()
df_orders_products_merged['average_price'] = df_orders_products_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     NaN         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   aisle_id  department_id  prices  _merge     busiest_day    busiest_days  \
# 0       77              7     9.0    both  Regularly busy  Regularly days
# 1       77              7     9.0    both  Regularly busy    Slowest days
# 2       77              7     9.0    both  Regularly busy    Slowest days
# 3       77              7     9.0    both      Least busy    Slowest days
# 4       77              7     9.0    both      Least busy    Slowest days
#
#   busiest_period_of_day max_order  loyalty_flag average_price
# 0        Average Orders        10  New customer      6.367797
# 1        Average Orders        10  New customer      6.367797
# 2           Most Orders        10  New customer      6.367797
# 3        Average Orders        10  New customer      6.367797
# 4           Most Orders        10  New customer      6.367797
#
# [5 rows x 21 columns]

# %% [markdown]
# Create Spending flag

# %%
df_orders_products_merged.loc[df_orders_products_merged['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
df_orders_products_merged.loc[df_orders_products_merged['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     NaN         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   department_id  prices  _merge     busiest_day    busiest_days  \
# 0             7     9.0    both  Regularly busy  Regularly days
# 1             7     9.0    both  Regularly busy    Slowest days
# 2             7     9.0    both  Regularly busy    Slowest days
# 3             7     9.0    both      Least busy    Slowest days
# 4             7     9.0    both      Least busy    Slowest days
#
#   busiest_period_of_day max_order  loyalty_flag  average_price spending_flag
# 0        Average Orders        10  New customer       6.367797   Low spender
# 1        Average Orders        10  New customer       6.367797   Low spender
# 2           Most Orders        10  New customer       6.367797   Low spender
# 3        Average Orders        10  New customer       6.367797   Low spender
# 4           Most Orders        10  New customer       6.367797   Low spender
#
# [5 rows x 22 columns]

# %%
# Check frequencies of spending flags for accuracy
df_orders_products_merged['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31798751
# High spender      635461
# Name: count, dtype: int64

# %% [markdown]
# # Step 7 - Customer frequency

# %%
# Create “median_prior_orders” column using transform()
df_orders_products_merged['median_prior_orders'] = df_orders_products_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     NaN         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   prices  _merge     busiest_day    busiest_days busiest_period_of_day  \
# 0    9.0    both  Regularly busy  Regularly days        Average Orders
# 1    9.0    both  Regularly busy    Slowest days        Average Orders
# 2    9.0    both  Regularly busy    Slowest days           Most Orders
# 3    9.0    both      Least busy    Slowest days        Average Orders
# 4    9.0    both      Least busy    Slowest days           Most Orders
#
#   max_order  loyalty_flag average_price  spending_flag median_prior_orders
# 0        10  New customer      6.367797    Low spender                20.5
# 1        10  New customer      6.367797    Low spender                20.5
# 2        10  New customer      6.367797    Low spender                20.5
# 3        10  New customer      6.367797    Low spender                20.5
# 4        10  New customer      6.367797    Low spender                20.5
#
# [5 rows x 23 columns]

# %% [markdown]
# Creating Order Frequency flag

# %%
df_orders_products_merged.loc[df_orders_products_merged['median_prior_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['median_prior_orders'] > 10) & (df_orders_products_merged['median_prior_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
df_orders_products_merged.loc[df_orders_products_merged['median_prior_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  ...  \
# 0                     NaN         196                  1          0  ...
# 1                    15.0         196                  1          1  ...
# 2                    21.0         196                  1          1  ...
# 3                    29.0         196                  1          1  ...
# 4                    28.0         196                  1          1  ...
#
#   _merge     busiest_day    busiest_days  busiest_period_of_day max_order  \
# 0   both  Regularly busy  Regularly days         Average Orders        10
# 1   both  Regularly busy    Slowest days         Average Orders        10
# 2   both  Regularly busy    Slowest days            Most Orders        10
# 3   both      Least busy    Slowest days         Average Orders        10
# 4   both      Least busy    Slowest days            Most Orders        10
#
#    loyalty_flag average_price spending_flag  median_prior_orders  \
# 0  New customer      6.367797   Low spender                 20.5
# 1  New customer      6.367797   Low spender                 20.5
# 2  New customer      6.367797   Low spender                 20.5
# 3  New customer      6.367797   Low spender                 20.5
# 4  New customer      6.367797   Low spender                 20.5
#
#     order_frequency_flag
# 0  Non-frequent customer
# 1  Non-frequent customer
# 2  Non-frequent customer
# 3  Non-frequent customer
# 4  Non-frequent customer
#
# [5 rows x 24 columns]

# %%
# Frequency check
df_orders_products_merged['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        21577409
# Regular customer          7217134
# Non-frequent customer     3639669
# Name: count, dtype: int64

# %% [markdown]
# # Step 8 - Ensure notebook is clean, structured and code is well commented

# %% [markdown]
# Done

# %% [markdown]
# # Step 9 - Export dataframe as pickle file

# %%
df_orders_products_merged.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_merged_V3.pkl'))
